# %%
from kafka import KafkaConsumer
import json
import io
import avro


def fetch_schema():
    from confluent_kafka.schema_registry import SchemaRegistryClient

    sr = SchemaRegistryClient({"url": "http://localhost:8081"})
    subjects = sr.get_subjects()
    schemas = []
    for subject in subjects:
        schema = sr.get_latest_version(subject)
        # print(schema.version)
        # print(schema.schema_id)
        # print(schema.schema.schema_str)
        schema_json = json.loads(schema.schema.schema_str)

        if schema_json["name"] == "Envelope":
            schemas.append(schema.schema.schema_str)

    return schemas


def decode_method(string: bytes, schema: str):
    avro_schema = avro.schema.parse(schema)
    reader = avro.io.DatumReader(avro_schema)

    message_bytes = io.BytesIO(string)
    message_bytes.seek(5)
    decoder = avro.io.BinaryDecoder(message_bytes)
    event_dict = reader.read(decoder)
    return event_dict


consumer = KafkaConsumer(
    bootstrap_servers=["localhost:29092"],
    auto_offset_reset="earliest",
    enable_auto_commit=False,
    # value_deserializer=lambda x: decode_method(x),
)

consumer.subscribe(
    ["postgres.sales.users", "postgres.sales.products", "postgres.sales.orders"]
)

# %%
schemas = fetch_schema()

# %%
for message in consumer:
    # find schema
    for s in schemas:
        if json.loads(s)["namespace"] == message.topic:
            schema = s
            break

    decoded_value = decode_method(message.value, schema)
    print(f"topic_name: {message.topic}, value: {decoded_value}")
# Out:
# topic_name: postgres.sales.users, value: b'{"schema":{"type":"struct","fields":[{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"string","optional":false,"field":"name"},{"type":"string","optional":false,"field":"email"},{"type":"string","optional":false,"field":"password"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.users.Value","field":"before"},{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"string","optional":false,"field":"name"},{"type":"string","optional":false,"field":"email"},{"type":"string","optional":false,"field":"password"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.users.Value","field":"after"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"version"},{"type":"string","optional":false,"field":"connector"},{"type":"string","optional":false,"field":"name"},{"type":"int64","optional":false,"field":"ts_ms"},{"type":"string","optional":true,"name":"io.debezium.data.Enum","version":1,"parameters":{"allowed":"true,last,false"},"default":"false","field":"snapshot"},{"type":"string","optional":false,"field":"db"},{"type":"string","optional":false,"field":"schema"},{"type":"string","optional":false,"field":"table"},{"type":"int64","optional":true,"field":"txId"},{"type":"int64","optional":true,"field":"lsn"},{"type":"int64","optional":true,"field":"xmin"}],"optional":false,"name":"io.debezium.connector.postgresql.Source","field":"source"},{"type":"string","optional":false,"field":"op"},{"type":"int64","optional":true,"field":"ts_ms"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"id"},{"type":"int64","optional":false,"field":"total_order"},{"type":"int64","optional":false,"field":"data_collection_order"}],"optional":true,"field":"transaction"}],"optional":false,"name":"postgres.sales.users.Envelope"},"payload":{"before":null,"after":{"id":176,"name":"Aurora da Mata","email":"ana-cecilia73@example.net","password":"d(ky3fVu_g","created_at":1720292969723828,"updated_at":1720292969723828,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720292969734,"snapshot":"false","db":"levicdc","schema":"sales","table":"users","txId":903,"lsn":27936528,"xmin":null},"op":"c","ts_ms":1720292969764,"transaction":null}}'
# topic_name: postgres.sales.users, value: b'{"schema":{"type":"struct","fields":[{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"string","optional":false,"field":"name"},{"type":"string","optional":false,"field":"email"},{"type":"string","optional":false,"field":"password"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.users.Value","field":"before"},{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"string","optional":false,"field":"name"},{"type":"string","optional":false,"field":"email"},{"type":"string","optional":false,"field":"password"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.users.Value","field":"after"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"version"},{"type":"string","optional":false,"field":"connector"},{"type":"string","optional":false,"field":"name"},{"type":"int64","optional":false,"field":"ts_ms"},{"type":"string","optional":true,"name":"io.debezium.data.Enum","version":1,"parameters":{"allowed":"true,last,false"},"default":"false","field":"snapshot"},{"type":"string","optional":false,"field":"db"},{"type":"string","optional":false,"field":"schema"},{"type":"string","optional":false,"field":"table"},{"type":"int64","optional":true,"field":"txId"},{"type":"int64","optional":true,"field":"lsn"},{"type":"int64","optional":true,"field":"xmin"}],"optional":false,"name":"io.debezium.connector.postgresql.Source","field":"source"},{"type":"string","optional":false,"field":"op"},{"type":"int64","optional":true,"field":"ts_ms"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"id"},{"type":"int64","optional":false,"field":"total_order"},{"type":"int64","optional":false,"field":"data_collection_order"}],"optional":true,"field":"transaction"}],"optional":false,"name":"postgres.sales.users.Envelope"},"payload":{"before":null,"after":{"id":177,"name":"Dra. Jade Cavalcante","email":"wcarvalho@example.net","password":"f9igJBc6@z","created_at":1720292994844541,"updated_at":1720292994844541,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720292994850,"snapshot":"false","db":"levicdc","schema":"sales","table":"users","txId":904,"lsn":27962320,"xmin":null},"op":"c","ts_ms":1720292995063,"transaction":null}}'
# topic_name: postgres.sales.users, value: b'{"before":null,"after":{"id":178,"name":"Valentim Campos","email":"lsilva@example.com","password":")2BKPrltY5","created_at":1720293218468312,"updated_at":1720293218468312,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720293218474,"snapshot":"false","db":"levicdc","schema":"sales","table":"users","txId":905,"lsn":27963280,"xmin":null},"op":"c","ts_ms":1720293218515,"transaction":null}'
# topic_name: postgres.sales.users, value: b'{"before":null,"after":{"id":179,"name":"Srta. Maria Vit\xc3\xb3ria Guerra","email":"albuquerquehadassa@example.net","password":"6+xYzn0u@2","created_at":1720297016140302,"updated_at":1720297016140302,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720297016148,"snapshot":"false","db":"levicdc","schema":"sales","table":"users","txId":906,"lsn":27990024,"xmin":null},"op":"c","ts_ms":1720297016389,"transaction":null}'
# topic_name: postgres.sales.products, value: b'{"schema":{"type":"struct","fields":[{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"string","optional":false,"field":"name"},{"type":"double","optional":false,"field":"price"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.products.Value","field":"before"},{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"string","optional":false,"field":"name"},{"type":"double","optional":false,"field":"price"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.products.Value","field":"after"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"version"},{"type":"string","optional":false,"field":"connector"},{"type":"string","optional":false,"field":"name"},{"type":"int64","optional":false,"field":"ts_ms"},{"type":"string","optional":true,"name":"io.debezium.data.Enum","version":1,"parameters":{"allowed":"true,last,false"},"default":"false","field":"snapshot"},{"type":"string","optional":false,"field":"db"},{"type":"string","optional":false,"field":"schema"},{"type":"string","optional":false,"field":"table"},{"type":"int64","optional":true,"field":"txId"},{"type":"int64","optional":true,"field":"lsn"},{"type":"int64","optional":true,"field":"xmin"}],"optional":false,"name":"io.debezium.connector.postgresql.Source","field":"source"},{"type":"string","optional":false,"field":"op"},{"type":"int64","optional":true,"field":"ts_ms"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"id"},{"type":"int64","optional":false,"field":"total_order"},{"type":"int64","optional":false,"field":"data_collection_order"}],"optional":true,"field":"transaction"}],"optional":false,"name":"postgres.sales.products.Envelope"},"payload":{"before":null,"after":{"id":176,"name":"Hat","price":93.03,"created_at":1720292969723828,"updated_at":1720292969723828,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720292969734,"snapshot":"false","db":"levicdc","schema":"sales","table":"products","txId":903,"lsn":27942488,"xmin":null},"op":"c","ts_ms":1720292969764,"transaction":null}}'
# topic_name: postgres.sales.products, value: b'{"schema":{"type":"struct","fields":[{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"string","optional":false,"field":"name"},{"type":"double","optional":false,"field":"price"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.products.Value","field":"before"},{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"string","optional":false,"field":"name"},{"type":"double","optional":false,"field":"price"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.products.Value","field":"after"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"version"},{"type":"string","optional":false,"field":"connector"},{"type":"string","optional":false,"field":"name"},{"type":"int64","optional":false,"field":"ts_ms"},{"type":"string","optional":true,"name":"io.debezium.data.Enum","version":1,"parameters":{"allowed":"true,last,false"},"default":"false","field":"snapshot"},{"type":"string","optional":false,"field":"db"},{"type":"string","optional":false,"field":"schema"},{"type":"string","optional":false,"field":"table"},{"type":"int64","optional":true,"field":"txId"},{"type":"int64","optional":true,"field":"lsn"},{"type":"int64","optional":true,"field":"xmin"}],"optional":false,"name":"io.debezium.connector.postgresql.Source","field":"source"},{"type":"string","optional":false,"field":"op"},{"type":"int64","optional":true,"field":"ts_ms"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"id"},{"type":"int64","optional":false,"field":"total_order"},{"type":"int64","optional":false,"field":"data_collection_order"}],"optional":true,"field":"transaction"}],"optional":false,"name":"postgres.sales.products.Envelope"},"payload":{"before":null,"after":{"id":177,"name":"Rustic Wooden Fish","price":38.29,"created_at":1720292994844541,"updated_at":1720292994844541,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720292994850,"snapshot":"false","db":"levicdc","schema":"sales","table":"products","txId":904,"lsn":27962520,"xmin":null},"op":"c","ts_ms":1720292995064,"transaction":null}}'
# topic_name: postgres.sales.products, value: b'{"before":null,"after":{"id":178,"name":"Frozen Pants","price":48.95,"created_at":1720293218468312,"updated_at":1720293218468312,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720293218474,"snapshot":"false","db":"levicdc","schema":"sales","table":"products","txId":905,"lsn":27969512,"xmin":null},"op":"c","ts_ms":1720293218516,"transaction":null}'
# topic_name: postgres.sales.products, value: b'{"before":null,"after":{"id":179,"name":"Sleek Granite Car","price":25.16,"created_at":1720297016140302,"updated_at":1720297016140302,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720297016148,"snapshot":"false","db":"levicdc","schema":"sales","table":"products","txId":906,"lsn":27996416,"xmin":null},"op":"c","ts_ms":1720297016390,"transaction":null}'
# topic_name: postgres.sales.orders, value: b'{"schema":{"type":"struct","fields":[{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"int32","optional":false,"field":"user_id"},{"type":"int32","optional":false,"field":"product_id"},{"type":"int32","optional":false,"field":"quantity"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.orders.Value","field":"before"},{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"int32","optional":false,"field":"user_id"},{"type":"int32","optional":false,"field":"product_id"},{"type":"int32","optional":false,"field":"quantity"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.orders.Value","field":"after"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"version"},{"type":"string","optional":false,"field":"connector"},{"type":"string","optional":false,"field":"name"},{"type":"int64","optional":false,"field":"ts_ms"},{"type":"string","optional":true,"name":"io.debezium.data.Enum","version":1,"parameters":{"allowed":"true,last,false"},"default":"false","field":"snapshot"},{"type":"string","optional":false,"field":"db"},{"type":"string","optional":false,"field":"schema"},{"type":"string","optional":false,"field":"table"},{"type":"int64","optional":true,"field":"txId"},{"type":"int64","optional":true,"field":"lsn"},{"type":"int64","optional":true,"field":"xmin"}],"optional":false,"name":"io.debezium.connector.postgresql.Source","field":"source"},{"type":"string","optional":false,"field":"op"},{"type":"int64","optional":true,"field":"ts_ms"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"id"},{"type":"int64","optional":false,"field":"total_order"},{"type":"int64","optional":false,"field":"data_collection_order"}],"optional":true,"field":"transaction"}],"optional":false,"name":"postgres.sales.orders.Envelope"},"payload":{"before":null,"after":{"id":236,"user_id":1,"product_id":1,"quantity":4,"created_at":1720292969723828,"updated_at":1720292969723828,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720292969734,"snapshot":"false","db":"levicdc","schema":"sales","table":"orders","txId":903,"lsn":27951256,"xmin":null},"op":"c","ts_ms":1720292969765,"transaction":null}}'
# topic_name: postgres.sales.orders, value: b'{"schema":{"type":"struct","fields":[{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"int32","optional":false,"field":"user_id"},{"type":"int32","optional":false,"field":"product_id"},{"type":"int32","optional":false,"field":"quantity"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.orders.Value","field":"before"},{"type":"struct","fields":[{"type":"int32","optional":false,"field":"id"},{"type":"int32","optional":false,"field":"user_id"},{"type":"int32","optional":false,"field":"product_id"},{"type":"int32","optional":false,"field":"quantity"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"created_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"updated_at"},{"type":"int64","optional":true,"name":"io.debezium.time.MicroTimestamp","version":1,"field":"deleted_at"}],"optional":true,"name":"postgres.sales.orders.Value","field":"after"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"version"},{"type":"string","optional":false,"field":"connector"},{"type":"string","optional":false,"field":"name"},{"type":"int64","optional":false,"field":"ts_ms"},{"type":"string","optional":true,"name":"io.debezium.data.Enum","version":1,"parameters":{"allowed":"true,last,false"},"default":"false","field":"snapshot"},{"type":"string","optional":false,"field":"db"},{"type":"string","optional":false,"field":"schema"},{"type":"string","optional":false,"field":"table"},{"type":"int64","optional":true,"field":"txId"},{"type":"int64","optional":true,"field":"lsn"},{"type":"int64","optional":true,"field":"xmin"}],"optional":false,"name":"io.debezium.connector.postgresql.Source","field":"source"},{"type":"string","optional":false,"field":"op"},{"type":"int64","optional":true,"field":"ts_ms"},{"type":"struct","fields":[{"type":"string","optional":false,"field":"id"},{"type":"int64","optional":false,"field":"total_order"},{"type":"int64","optional":false,"field":"data_collection_order"}],"optional":true,"field":"transaction"}],"optional":false,"name":"postgres.sales.orders.Envelope"},"payload":{"before":null,"after":{"id":237,"user_id":1,"product_id":1,"quantity":2,"created_at":1720292994844541,"updated_at":1720292994844541,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720292994850,"snapshot":"false","db":"levicdc","schema":"sales","table":"orders","txId":904,"lsn":27962688,"xmin":null},"op":"c","ts_ms":1720292995065,"transaction":null}}'
# topic_name: postgres.sales.orders, value: b'{"before":null,"after":{"id":238,"user_id":1,"product_id":1,"quantity":5,"created_at":1720293218468312,"updated_at":1720293218468312,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720293218474,"snapshot":"false","db":"levicdc","schema":"sales","table":"orders","txId":905,"lsn":27978464,"xmin":null},"op":"c","ts_ms":1720293218517,"transaction":null}'
# topic_name: postgres.sales.orders, value: b'{"before":null,"after":{"id":239,"user_id":1,"product_id":1,"quantity":3,"created_at":1720297016140302,"updated_at":1720297016140302,"deleted_at":null},"source":{"version":"1.4.2.Final","connector":"postgresql","name":"postgres","ts_ms":1720297016148,"snapshot":"false","db":"levicdc","schema":"sales","table":"orders","txId":906,"lsn":28005464,"xmin":null},"op":"c","ts_ms":1720297016391,"transaction":null}'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 for message in consumer:
#       2     print(f"topic_name: {message.topic}, value: {message.value}")
#       4     # json_str = json.loads(message.value)
#
# File c:\Users\levyv\Documents\proj\send-data-to-postgresql\.venv\Lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File c:\Users\levyv\Documents\proj\send-data-to-postgresql\.venv\Lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File c:\Users\levyv\Documents\proj\send-data-to-postgresql\.venv\Lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File c:\Users\levyv\Documents\proj\send-data-to-postgresql\.venv\Lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File c:\Users\levyv\Documents\proj\send-data-to-postgresql\.venv\Lib\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File c:\Users\levyv\Documents\proj\send-data-to-postgresql\.venv\Lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File c:\Users\levyv\Documents\proj\send-data-to-postgresql\.venv\Lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:
